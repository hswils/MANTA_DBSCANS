# %%
conda activate omfitenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from omfit_classes import omfit_eqdsk
# Out:
# UserWarning: No `MDSplus` support: ModuleNotFoundError("No module named 'MDSplus'") (omfit_mds.py@24)

# %%
from netCDF4 import Dataset
import matplotlib.pyplot as pyplot
from uncertainties import ufloat
import numpy as np
from scipy.integrate import cumtrapz
from scipy.constants import mu_0
import os

# %%
def plot(self,gEQDSK=None, showSlowFast=False):
 with pyplot.style.context('default'):
    fig = pyplot.gcf()
    fig.set_size_inches(16, 8)
    ax0 = pyplot.subplot(131)
    if gEQDSK is None:
        gEQDSK = {}
        gEQDSK['RHORZ'] = self['eqdsk_psi']['data']
        gEQDSK['R'] = self['eqdsk_r']['data']
        gEQDSK['Z'] = self['eqdsk_z']['data']
        n = 10
        flx = fluxSurfaces(
            Rin=self['eqdsk_r']['data'],
            Zin=self['eqdsk_z']['data'],
            PSIin=self['eqdsk_psi']['data'],
            Btin=self['eqdsk_psi']['data'] * 0,
            levels=n,
            quiet=True,
            cocosin=1,
        )
        for k in range(n):
            pyplot.plot(flx['flux'][k]['R'], flx['flux'][k]['Z'], 'k', linewidth=0.5)
        pyplot.xlabel('R')
        pyplot.ylabel('Z')
    else:
        gEQDSK.plot(only2D=True)
        flx = gEQDSK['fluxSurfaces']
    pyplot.title('Ray trajectories')
    rho = self['rho_bin_center'][:]
    powden = self['powden'][:]
    powden_e = self['powden_e'][:]
    powden_i = self['powden_i'][:]
    powtot_e = self['powtot_e'][:]
    powtot_i = self['powtot_i'][:]
    powtot = self['power_total'][:]
    cur_parallel = self['s_cur_den_parallel'][:]
    curtotal_parallel = self['parallel_cur_total'][:]
    powden = powden / 1e7  # ergs/sec/cm^3 to W/cm^3 = MW/m^3
    powden_e = powden_e / 1e7  # ergs/sec/cm^3 to W/cm^3 = MW/m^3
    powden_i = powden_i / 1e7  # ergs/sec/cm^3 to W/cm^3 = MW/m^3
    powtot_elec = powtot_e / 1e7 / 1e6  # from ergs/sec to W, and to MW
    powtot_ions = powtot_i / 1e7 / 1e6
    powtot = powtot / 1e7 / 1e6
    cur_parallel = cur_parallel / 1e2  # from A/cm^2 to MA/m^2
    curtotal_parallel = curtotal_parallel / 1e3  # from A to kA
    npar = self['wnpar'][:].flatten()
    wr_vals = self['wr'][:].flatten()
    wz_vals = self['wz'][:].flatten()
    wphi_vals = self['wphi'][:].flatten()
    rho_ray = self['spsi'][:].flatten()
    btot_ray = self['sbtot'][:].flatten()
    dpol = self['ws'][:].flatten()
    dpol = dpol / 1e2  # from cm to m
    wr_vals = wr_vals / 1e2  # from cm to m
    wz_vals = wz_vals / 1e2  # from cm to m
    raypower = self['delpwr'][:].flatten()
    raypower = raypower / 1e7 / 1e6  # from ergs/sec to W, and to MW
    deriv_raypower = abs(np.gradient(raypower, dpol))  # in MW/m
    deriv_raypower[np.isinf(deriv_raypower)] = 0
    dpolmax = max(dpol)
    wr_vals[wr_vals == 0] = np.nan
    wz_vals[wz_vals == 0] = np.nan
    wphi_vals[wphi_vals == 0] = np.nan
    dpol[dpol == 0] = np.nan
    ray_Te = self['ste'][:].flatten()
    vpar = 3e10 / abs(npar)
    vthe = 4.19e7 * np.sqrt(2 * ray_Te * 1e3)  # ray_Te was in keV, using sqrt(2Te/m) as thermal velocity
    # ax0 = pyplot.subplot(131)
    pyplot.scatter(wr_vals, wz_vals, c='k', edgecolor='None', s=deriv_raypower / max(deriv_raypower) * 200, marker=',', alpha=0.1)
    myplot = pyplot.scatter(wr_vals, wz_vals, c=(raypower / max(raypower)), cmap='rainbow', edgecolor='None', marker='.')
    pyplot.xlabel('R (m)')
    pyplot.ylabel('Z (m)')
    pyplot.title('Ray trajectory')
    pyplot.axis('image')
    #pyplot.colorbar(myplot, ax=ax0, norm=raypower, label='Power in ray (MW)')
    ax0 = pyplot.subplot(232)
    angles = np.arange(0, 6.3, 0.05)
    pyplot.scatter(
        wr_vals * np.cos(wphi_vals),
        wr_vals * np.sin(wphi_vals),
        c='k',
        edgecolor='None',
        s=deriv_raypower / max(deriv_raypower) * 200,
        marker=',',
        alpha=0.1,
    )
    myplot = pyplot.scatter(
        wr_vals * np.cos(wphi_vals),
        wr_vals * np.sin(wphi_vals),
        c=(raypower / max(raypower)),
        cmap='rainbow',
        edgecolor='None',
        marker='.',
    )
    Rmax_psin1 = max(flx['geo']['Rmax_centroid'])
    R_psin0 = min(flx['geo']['Rmax_centroid'])
    Rmin_psin1 = min(flx['geo']['Rmin_centroid'])
    pyplot.plot(Rmax_psin1 * np.cos(angles), Rmax_psin1 * np.sin(angles), 'k')
    pyplot.plot(R_psin0 * np.cos(angles), R_psin0 * np.sin(angles), 'k', linestyle='dashed')
    pyplot.plot(Rmin_psin1 * np.cos(angles), Rmin_psin1 * np.sin(angles), 'k')
    pyplot.xlabel('X (m)')
    pyplot.ylabel('Y (m)')
    pyplot.title('Ray trajectory')
    pyplot.axis('image')
    pyplot.colorbar(myplot, ax=ax0, norm=raypower, label='Power in ray (MW)')
    ax = pyplot.subplot(235)
    ax.clear()
    pyplot.plot(rho, powden, label='Total {:.2f} MW'.format(powtot), linewidth=1.5)
    pyplot.plot(rho, powden_e, label='Electrons {:.2f} MW'.format(powtot_elec), linewidth=1.5)
    pyplot.plot(rho, powden_i, label='Ions {:.2f} MW'.format(powtot_ions), linewidth=1.5)
    pyplot.legend(fontsize='medium', framealpha=0.2, frameon=0, loc='upper left')
    pyplot.xlabel('$\\rho$')
    pyplot.ylabel('Power density (MW/m$^3$)')
    pyplot.axis('tight')
    ax2 = ax.twinx()
    pyplot.plot(rho, cur_parallel, color='darkorange', label='$J_\parallel$ {:.1f} kA'.format(curtotal_parallel), linewidth=1.5)
    pyplot.ylabel('$J_\parallel$ (MA/m$^2$)')
    pyplot.title('$P_{abs}$ & CD')
    pyplot.legend(fontsize='medium', framealpha=0.2, frameon=0, loc='upper right')
    pyplot.axis('tight')
    ax3 = pyplot.subplot(233)
    ax3.clear()
    pyplot.plot(dpol, npar, c='r', label='Rainbow line: $n_\parallel$', linewidth=0)
    pyplot.scatter(dpol, npar, c='k', edgecolor='none', marker='.', s=deriv_raypower / max(deriv_raypower) * 1000, alpha=0.1)
    pyplot.scatter(dpol, npar, c=(raypower / max(raypower)), cmap='rainbow', edgecolor='none', marker='.')
    pyplot.xlabel('Distance along ray (m)')
    pyplot.ylabel('$n_\parallel$')
    ax4 = ax3.twinx()
    pyplot.plot(dpol, vpar / vthe, c='g', label='Green line: $v_\\parallel/v_{th,e}$', linewidth=0)
    pyplot.scatter(dpol, vpar / vthe, c='g', edgecolor='none', marker='.', s=deriv_raypower / max(deriv_raypower) * 1000, alpha=0.1)
    pyplot.plot(dpol, vpar / vthe, c='g')
    pyplot.ylabel('$v_\\parallel/v_{th,e}$')
    pyplot.xlim(0, dpolmax)
    pyplot.title('Green line: $v_\\parallel/v_{th,e}$  Rainbow line: $n_\parallel$')
    pyplot.axis('tight')
    ax5 = pyplot.subplot(236)
    pyplot.plot(vpar / vthe, deriv_raypower, c='b')
    pyplot.xlabel('$v_\\parallel/v_{th,e}$')
    pyplot.ylabel('Ray absorption (MW/m)')
    pyplot.xlim(0, 5)
    pyplot.subplots_adjust(hspace=0.4, left=0.03, wspace=0.4, right=0.95)

# %%
#get files

sim_index = 7

cwd = os.getcwd()
SCAN_dir = cwd+'/SCAN'

sims = [f for f in os.listdir(SCAN_dir) if f.startswith('simulation_') and not f.endswith('.conf') and not f.endswith('log')]

sim = sims[sim_index]
work_dir = SCAN_dir+'/'+sim+'/work'

genray_dir = [f for f in os.listdir(work_dir) if f.startswith('fastran_lh_')]
lhfile = work_dir+'/'+genray_dir[0]+'/genray.nc'
gfile = work_dir+'/'+genray_dir[0]+'/g000001.00001'

#rootgrp = Dataset(ffile)
geqdsk = omfit_eqdsk.OMFITgeqdsk(gfile)
lhgrp = Dataset(lhfile)

print(work_dir)
# Out:
# /pscratch/sd/h/hswils/github_repos/MANTA_DBSCANS/SCANS_GENRAY/npar_scan/SCAN/simulation_440388_0003/work

# %%
plot(lhgrp,gEQDSK=geqdsk)
pyplot.show()
#bad: 2, 4, 6, 7, 8

# %%
'''genray_lh  GRILL_ANMIN_0  -2.100000000000000e+00
genray_lh  GRILL_ANMAX_0  -1.500000000000000e+00
genray_lh  GRILL_THGRILL_0  1.400000000000000e+02 is bad'''

'''genray_lh  GRILL_ANMIN_0  -2.100000000000000e+00
genray_lh  GRILL_ANMAX_0  -1.500000000000000e+00
genray_lh  GRILL_THGRILL_0  2.200000000000000e+02 is bad'''

'''genray_lh  GRILL_ANMIN_0  -2.100000000000000e+00
genray_lh  GRILL_ANMAX_0  -1.500000000000000e+00
genray_lh  GRILL_THGRILL_0  1.800000000000000e+02 is bad'''

'''genray_lh  GRILL_ANMIN_0  -1.200000000000000e+00
genray_lh  GRILL_ANMAX_0  -6.000000000000000e-01
genray_lh  GRILL_THGRILL_0  1.400000000000000e+02 worked but gave a bad result'''
# Out:
# {'version': <class 'netCDF4._netCDF4.Variable'>
# |S1 version(char64dim)
#     long_name: GENRAY version number
# unlimited dimensions:
# current shape = (64,)
# filling on, default _FillValue of  used, 'mnemonic': <class 'netCDF4._netCDF4.Variable'>
# |S1 mnemonic(char128dim)
#     long_name: Mnemonic run identifier
# unlimited dimensions:
# current shape = (128,)
# filling on, default _FillValue of  used, 'id': <class 'netCDF4._netCDF4.Variable'>
# int32 id()
#     long_name: Disp relation identifier
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'iabsorp': <class 'netCDF4._netCDF4.Variable'>
# int32 iabsorp()
#     long_name: Absorp calc identifier
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'ieffic': <class 'netCDF4._netCDF4.Variable'>
# int32 ieffic()
#     long_name: Current drive calc identifier
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'ion_absorption': <class 'netCDF4._netCDF4.Variable'>
# |S1 ion_absorption(char8dim)
#     long_name: Switch on/off ion absorption at iabsorp=3,9,91,92
# unlimited dimensions:
# current shape = (8,)
# filling on, default _FillValue of  used, 'refl_loss': <class 'netCDF4._netCDF4.Variable'>
# float64 refl_loss()
#     long_name: fraction of power loss at each reflection
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'iflux': <class 'netCDF4._netCDF4.Variable'>
# int32 iflux()
#     long_name: Flux calc, non-Westerhof-Tokman id
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'ioxm': <class 'netCDF4._netCDF4.Variable'>
# int32 ioxm()
#     long_name: wave mode indicator (1 - om, -1 - xm )
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'ioxm_n_npar': <class 'netCDF4._netCDF4.Variable'>
# int32 ioxm_n_npar()
#     long_name: wave mode indicator: sign before square root to find  N(N_parallel)
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'jwave': <class 'netCDF4._netCDF4.Variable'>
# int32 jwave()
#     long_name: Wave harmonic, for CD efficiency calc
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'i_geom_optic': <class 'netCDF4._netCDF4.Variable'>
# int32 i_geom_optic()
#     long_name: Integrate rays wrt (1)time,(2)dist
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'istart': <class 'netCDF4._netCDF4.Variable'>
# int32 istart()
#     long_name: Ray launch type: 1,eccone; 2,grill, 3,OX in plasma
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'ncone': <class 'netCDF4._netCDF4.Variable'>
# int32 ncone()
#     long_name0: Number of rf source ray cones, istart=1
#     long_name1: Each cone has (nray/ncone) launched rays
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'ngrill': <class 'netCDF4._netCDF4.Variable'>
# int32 ngrill()
#     long_name0: Number of rf source ray grills, istart=2,
#     long_name1: ,nray/ngrill rays launched per grill istart=2,3
#     long_name2: ,Each grill has (nray/ngrill) launched rays, istart=2,3
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'ionetwo': <class 'netCDF4._netCDF4.Variable'>
# int32 ionetwo()
#     long_name: if ionetwo=1 then calculate CD
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'nray': <class 'netCDF4._netCDF4.Variable'>
# int32 nray()
#     long_name: Number of rays
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'nharm': <class 'netCDF4._netCDF4.Variable'>
# int32 nharm()
#     long_name: First harmonic number
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'freqcy': <class 'netCDF4._netCDF4.Variable'>
# float64 freqcy()
#     long_name: Wave frequency
#     units: Hz
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'i_emission': <class 'netCDF4._netCDF4.Variable'>
# int32 i_emission()
#     long_name: emission switch: =0 now emission, =1 use emission calculations
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'i_emission_spectrum': <class 'netCDF4._netCDF4.Variable'>
# int32 i_emission_spectrum()
#     long_name: emission spectrum switch: =0 no emission spectrum,   =1 use emission spectrum  calculations
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'nrayelt': <class 'netCDF4._netCDF4.Variable'>
# int32 nrayelt(nrays)
#     long_name: Number of ray elements for each ray
# unlimited dimensions:
# current shape = (100,)
# filling on, default _FillValue of -2147483647 used, 'ws': <class 'netCDF4._netCDF4.Variable'>
# float64 ws(nrays, neltmax)
#     long_name: poloidal distance along a ray
#     units: cms
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'seikon': <class 'netCDF4._netCDF4.Variable'>
# float64 seikon(nrays, neltmax)
#     long_name: eikonal
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'spsi': <class 'netCDF4._netCDF4.Variable'>
# float64 spsi(nrays, neltmax)
#     long_name: normalized small radius=rho given by indexrho
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wr': <class 'netCDF4._netCDF4.Variable'>
# float64 wr(nrays, neltmax)
#     long_name: major radius
#     units: cms
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wphi': <class 'netCDF4._netCDF4.Variable'>
# float64 wphi(nrays, neltmax)
#     long_name: toroidal angle
#     units: rad
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wz': <class 'netCDF4._netCDF4.Variable'>
# float64 wz(nrays, neltmax)
#     long_name: vertical height
#     units: cms
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'w_theta_pol': <class 'netCDF4._netCDF4.Variable'>
# float64 w_theta_pol(nrays, neltmax)
#     long_name: poloidal angle
#     units: degree
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wnpar': <class 'netCDF4._netCDF4.Variable'>
# float64 wnpar(nrays, neltmax)
#     long_name: parallel refractive index
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wnper': <class 'netCDF4._netCDF4.Variable'>
# float64 wnper(nrays, neltmax)
#     long_name: perpendicular refractive index
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'delpwr': <class 'netCDF4._netCDF4.Variable'>
# float64 delpwr(nrays, neltmax)
#     long_name: power in ray channel
#     units: erg/sec
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sdpwr': <class 'netCDF4._netCDF4.Variable'>
# float64 sdpwr(nrays, neltmax)
#     long_name: Ion collisionless absorption coeff (all species)
#     units: 1/cms
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wdnpar': <class 'netCDF4._netCDF4.Variable'>
# float64 wdnpar(nrays, neltmax)
#     long_name: wdnpar
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cwexde': <class 'netCDF4._netCDF4.Variable'>
# float64 cwexde(two, nrays, neltmax)
#     long_name: Complex Ex/E Polarization
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweyde': <class 'netCDF4._netCDF4.Variable'>
# float64 cweyde(two, nrays, neltmax)
#     long_name: Complex Ey/E Polarization
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cwezde': <class 'netCDF4._netCDF4.Variable'>
# float64 cwezde(two, nrays, neltmax)
#     long_name: Complex Ez/E Polarization
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'fluxn': <class 'netCDF4._netCDF4.Variable'>
# float64 fluxn(nrays, neltmax)
#     long_name: fluxn, Stix norm, |E|=1
#     units: ergs/sec/cm^2
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sbtot': <class 'netCDF4._netCDF4.Variable'>
# float64 sbtot(nrays, neltmax)
#     long_name: Magnetic field strength
#     units: gauss
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sene': <class 'netCDF4._netCDF4.Variable'>
# float64 sene(nrays, neltmax)
#     long_name: Density along ray
#     units: particles/cm^3
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ste': <class 'netCDF4._netCDF4.Variable'>
# float64 ste(nrays, neltmax)
#     long_name: Temperature along ray
#     units: keV
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'szeff': <class 'netCDF4._netCDF4.Variable'>
# float64 szeff(nrays, neltmax)
#     long_name: Zeff along ray
#     units: dimensionless
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'salphac': <class 'netCDF4._netCDF4.Variable'>
# float64 salphac(nrays, neltmax)
#     long_name: Collisional damping wavenumber
#     units: 1/cms
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'salphal': <class 'netCDF4._netCDF4.Variable'>
# float64 salphal(nrays, neltmax)
#     long_name: Linear damping wavenumber
#     units: 1/cms
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sb_r': <class 'netCDF4._netCDF4.Variable'>
# float64 sb_r(nrays, neltmax)
#     long_name: B_r magnetic field component
#     units: guass
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sb_z': <class 'netCDF4._netCDF4.Variable'>
# float64 sb_z(nrays, neltmax)
#     long_name: B_z magnetic field component
#     units: guass
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sb_phi': <class 'netCDF4._netCDF4.Variable'>
# float64 sb_phi(nrays, neltmax)
#     long_name: B_phi magnetic field component
#     units: guass
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wn_r': <class 'netCDF4._netCDF4.Variable'>
# float64 wn_r(nrays, neltmax)
#     long_name: N_r refractive index component
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wn_z': <class 'netCDF4._netCDF4.Variable'>
# float64 wn_z(nrays, neltmax)
#     long_name: N_z refractive index component
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wn_phi': <class 'netCDF4._netCDF4.Variable'>
# float64 wn_phi(nrays, neltmax)
#     long_name: N_phi refractive index component
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'vgr_r': <class 'netCDF4._netCDF4.Variable'>
# float64 vgr_r(nrays, neltmax)
#     long_name: vgroup_r normalized to c
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'vgr_z': <class 'netCDF4._netCDF4.Variable'>
# float64 vgr_z(nrays, neltmax)
#     long_name: vgroup_z normalized to c
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'vgr_phi': <class 'netCDF4._netCDF4.Variable'>
# float64 vgr_phi(nrays, neltmax)
#     long_name: vgroup_phi normalized to c
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'flux_z': <class 'netCDF4._netCDF4.Variable'>
# float64 flux_z(nrays, neltmax)
#     long_name: flux_z normalized to c
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'flux_r': <class 'netCDF4._netCDF4.Variable'>
# float64 flux_r(nrays, neltmax)
#     long_name: flux_r normalized to c
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'flux_phi': <class 'netCDF4._netCDF4.Variable'>
# float64 flux_phi(nrays, neltmax)
#     long_name: flux_phi normalized to c
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'w_eff_nc': <class 'netCDF4._netCDF4.Variable'>
# float64 w_eff_nc(nrays, neltmax)
#     long_name: CD efficiency along a ray
#     units: (A/cm**2)/(erg/(sec*cm**3))
# unlimited dimensions:
# current shape = (100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'eqdskin': <class 'netCDF4._netCDF4.Variable'>
# |S1 eqdskin(char256dim)
#     long_name: Name of input eqdsk, for eqsource=eqdsk
# unlimited dimensions:
# current shape = (256,)
# filling on, default _FillValue of  used, 'nbulk': <class 'netCDF4._netCDF4.Variable'>
# int32 nbulk()
#     long_name: Number of Maxl plasma cmpts, electrons+ions
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'dmas': <class 'netCDF4._netCDF4.Variable'>
# float64 dmas(nbulk)
#     long_name: plasma species mass: electrons, then ions
#     units: Normalized to electron mass
# unlimited dimensions:
# current shape = (4,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'charge': <class 'netCDF4._netCDF4.Variable'>
# float64 charge(nbulk)
#     long_name: plasma species charge: electrons, then ions
#     units: Normalized to electronic charge
# unlimited dimensions:
# current shape = (4,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'w_tot_pow_absorb_at_refl_nc': <class 'netCDF4._netCDF4.Variable'>
# float64 w_tot_pow_absorb_at_refl_nc()
#     long_name: Total power absorbed at reflections of all rays
#     units: erg/sec
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nxeqd': <class 'netCDF4._netCDF4.Variable'>
# int32 nxeqd()
#     long_name: Number of r points
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'nyeqd': <class 'netCDF4._netCDF4.Variable'>
# int32 nyeqd()
#     long_name: Number of z points
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'eqdsk_r': <class 'netCDF4._netCDF4.Variable'>
# float64 eqdsk_r(nxeqd)
#     long_name: eqdsk r array
#     units: m
# unlimited dimensions:
# current shape = (129,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'eqdsk_z': <class 'netCDF4._netCDF4.Variable'>
# float64 eqdsk_z(nyeqd)
#     long_name: eqdsk z array
#     units: m
# unlimited dimensions:
# current shape = (129,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'eqdsk_psi': <class 'netCDF4._netCDF4.Variable'>
# float64 eqdsk_psi(nyeqd, nxeqd)
#     long_name: eqdsk poloidal flux
#     units:
# unlimited dimensions:
# current shape = (129, 129)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'z_starting': <class 'netCDF4._netCDF4.Variable'>
# float64 z_starting(nrays)
#     long_name: z_starting
#     units: m
# unlimited dimensions:
# current shape = (100,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'r_starting': <class 'netCDF4._netCDF4.Variable'>
# float64 r_starting(nrays)
#     long_name: r_starting
#     units: m
# unlimited dimensions:
# current shape = (100,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'phi_starting': <class 'netCDF4._netCDF4.Variable'>
# float64 phi_starting(nrays)
#     long_name: phi_starting
#     units: radian
# unlimited dimensions:
# current shape = (100,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'N_toroidal_starting': <class 'netCDF4._netCDF4.Variable'>
# float64 N_toroidal_starting(nrays)
#     long_name: N_toroidal_starting
#     units: non-dimensional
# unlimited dimensions:
# current shape = (100,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'N_poloidal_starting': <class 'netCDF4._netCDF4.Variable'>
# float64 N_poloidal_starting(nrays)
#     long_name: N_poloidal_starting
#     units: non-dimensional
# unlimited dimensions:
# current shape = (100,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'parallel_cur_total': <class 'netCDF4._netCDF4.Variable'>
# float64 parallel_cur_total()
#     long_name: Total parallel current
#     units: A
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'toroidal_cur_total': <class 'netCDF4._netCDF4.Variable'>
# float64 toroidal_cur_total()
#     long_name: Total toroidal current
#     units: A
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'poloidal_cur_total': <class 'netCDF4._netCDF4.Variable'>
# float64 poloidal_cur_total()
#     long_name: Total poloidal current
#     units: A
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'power_inj_total': <class 'netCDF4._netCDF4.Variable'>
# float64 power_inj_total()
#     long_name: Total injected power
#     units: erg/sec
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'power_total': <class 'netCDF4._netCDF4.Variable'>
# float64 power_total()
#     long_name: Total absorbed power
#     units: erg/sec
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'powtot_e': <class 'netCDF4._netCDF4.Variable'>
# float64 powtot_e()
#     long_name: Total power to electrons
#     units: erg/sec
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'powtot_i': <class 'netCDF4._netCDF4.Variable'>
# float64 powtot_i()
#     long_name: Total power to ions
#     units: erg/sec
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'powtot_cl': <class 'netCDF4._netCDF4.Variable'>
# float64 powtot_cl()
#     long_name: Collisional power absorbed
#     units: erg/sec
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'NR': <class 'netCDF4._netCDF4.Variable'>
# int32 NR()
#     long_name: Number of small radius points
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'voltot': <class 'netCDF4._netCDF4.Variable'>
# float64 voltot()
#     long_name: Total volume in last closed flux surface
#     units: cm^3
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'areatot': <class 'netCDF4._netCDF4.Variable'>
# float64 areatot()
#     long_name: Total cross-sectional area of LCFS
#     units: cm^2
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pollentot': <class 'netCDF4._netCDF4.Variable'>
# float64 pollentot()
#     long_name: Poloidal length of LCFS
#     units: cm
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'torftot': <class 'netCDF4._netCDF4.Variable'>
# float64 torftot()
#     long_name: Toroidal flux through LCFS
#     units: Tesla*m^2
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'indexrho': <class 'netCDF4._netCDF4.Variable'>
# int32 indexrho()
#     long_name: Radial coord type: 2 gives sqrt(tor flx)
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'psifactr': <class 'netCDF4._netCDF4.Variable'>
# float64 psifactr()
#     long_name: Reduces Psi-Value of LCFS
#     units: Should be .le.1
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 'binvol': <class 'netCDF4._netCDF4.Variable'>
# float64 binvol(nrhom)
#     long_name: Volumes of radial bins
#     units: cm^3
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'binarea': <class 'netCDF4._netCDF4.Variable'>
# float64 binarea(nrhom)
#     long_name: Areas of radial bins
#     units: cm^2
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pollen': <class 'netCDF4._netCDF4.Variable'>
# float64 pollen(nrhom)
#     long_name: Poloidal lengths of radial bins
#     units: cm
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'rho_bin': <class 'netCDF4._netCDF4.Variable'>
# float64 rho_bin(nrho)
#     long_name: normalized small radius bin boundaries
# unlimited dimensions:
# current shape = (201,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'rho_bin_center': <class 'netCDF4._netCDF4.Variable'>
# float64 rho_bin_center(nrhom)
#     long_name: normalized small radius bin centers
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'densprof': <class 'netCDF4._netCDF4.Variable'>
# float64 densprof(nbulk, nrho)
#     long_name: plasma density at bin boundaries, e and ions
#     units: particles/cm^3
# unlimited dimensions:
# current shape = (4, 201)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'temprof': <class 'netCDF4._netCDF4.Variable'>
# float64 temprof(nbulk, nrho)
#     long_name: plasma temperatures at bin boundaries, e and ions
#     units: keV
# unlimited dimensions:
# current shape = (4, 201)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'zefprof': <class 'netCDF4._netCDF4.Variable'>
# float64 zefprof(nrho)
#     long_name: plasma Zeff at bin boundaries, e and ions
#     units: unitless
# unlimited dimensions:
# current shape = (201,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'spower': <class 'netCDF4._netCDF4.Variable'>
# float64 spower(nrhom)
#     long_name: power per bin profile
#     units: erg/sec
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'w_r_densprof_nc': <class 'netCDF4._netCDF4.Variable'>
# float64 w_r_densprof_nc(nrho)
#     long_name: major radius r mesh for plasma profiles
#     units: m
# unlimited dimensions:
# current shape = (201,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'w_dens_vs_r_nc': <class 'netCDF4._netCDF4.Variable'>
# float64 w_dens_vs_r_nc(nbulk, nrho)
#     long_name: plasma density at bin bndries, e and ions vs major radius
#     units: particles/m^3
# unlimited dimensions:
# current shape = (4, 201)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'w_temp_vs_r_nc': <class 'netCDF4._netCDF4.Variable'>
# float64 w_temp_vs_r_nc(nbulk, nrho)
#     long_name: plasma temperatures at bin bndries, e and ions vs major radius
#     units: keV
# unlimited dimensions:
# current shape = (4, 201)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'w_zeff_vs_r_nc': <class 'netCDF4._netCDF4.Variable'>
# float64 w_zeff_vs_r_nc(nrho)
#     long_name: plasma Zeff at bin bndries vs major radius
#     units: unitless
# unlimited dimensions:
# current shape = (201,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'GA_tor_cur_total': <class 'netCDF4._netCDF4.Variable'>
# float64 GA_tor_cur_total()
#     long_name: GA memo total toroidal current
#     units: A
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used, 's_cur_den_parallel': <class 'netCDF4._netCDF4.Variable'>
# float64 s_cur_den_parallel(nrhom)
#     long_name: averaged parallel current density profile
#     units: A/cm**2
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 's_cur_den_onetwo': <class 'netCDF4._netCDF4.Variable'>
# float64 s_cur_den_onetwo(nrhom)
#     long_name: ONETWO current <j.B>/B_0 density profile
#     units: A/cm**2
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 's_cur_den_toroidal': <class 'netCDF4._netCDF4.Variable'>
# float64 s_cur_den_toroidal(nrhom)
#     long_name: toroidal current <j_par>f<1/r**2>/(<B><1/r>) density profile
#     units: A/cm**2
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 's_cur_den_poloidal': <class 'netCDF4._netCDF4.Variable'>
# float64 s_cur_den_poloidal(nrhom)
#     long_name: poloidal current <j_par>B_pol(theta_pol=0)/<B> density profile
#     units: A/cm**2
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'powden': <class 'netCDF4._netCDF4.Variable'>
# float64 powden(nrhom)
#     long_name: power density profile
#     units: erg/(cm**3*sec)
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'powden_e': <class 'netCDF4._netCDF4.Variable'>
# float64 powden_e(nrhom)
#     long_name0: power density profile to electrons, bin centered
#     long_name1: From wave-particle damping
#     units: erg/(cm**3*sec)
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'powden_cl': <class 'netCDF4._netCDF4.Variable'>
# float64 powden_cl(nrhom)
#     long_name0: power density profile to electrons, bin centered
#     long_name1: From collisional damping
#     units: erg/(cm**3*sec)
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'powden_i': <class 'netCDF4._netCDF4.Variable'>
# float64 powden_i(nrhom)
#     long_name: power density profile to ions, bin centered
#     long_name1: From wave-particle damping
#     units: erg/(cm**3*sec)
# unlimited dimensions:
# current shape = (200,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps11': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps11(two, nrays, neltmax)
#     long_name: Complex eps11
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps12': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps12(two, nrays, neltmax)
#     long_name: Complex eps12
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps13': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps13(two, nrays, neltmax)
#     long_name: Complex eps13
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps21': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps21(two, nrays, neltmax)
#     long_name: Complex eps21
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps22': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps22(two, nrays, neltmax)
#     long_name: Complex eps22
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps23': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps23(two, nrays, neltmax)
#     long_name: Complex eps23
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps31': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps31(two, nrays, neltmax)
#     long_name: Complex eps31
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps32': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps32(two, nrays, neltmax)
#     long_name: Complex eps32
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'cweps33': <class 'netCDF4._netCDF4.Variable'>
# float64 cweps33(two, nrays, neltmax)
#     long_name: Complex eps33
# unlimited dimensions:
# current shape = (2, 100, 1)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nfreq': <class 'netCDF4._netCDF4.Variable'>
# int32 nfreq()
#     long_name: The number of the emission frequencies
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used, 'iray_status_nc': <class 'netCDF4._netCDF4.Variable'>
# int32 iray_status_nc(nfreq, nrays)
#     long_name: Status code giving the reason each ray stops
#     long_name1: =-1 bad initial condition;
#     long_name2:  =1  t.gt.poldist_mx;
#     long_name3:  =2 in prep3d delpwr(is).lt.delpwrmn*delpwr(1)
#     long_name4:  =3  irefl.ge.ireflm;
#     long_name5:  =4  ray is at tor limiter bndry,  max_limiters.ge.1;
#     long_name6:  =5  nstep_rk.gt.maxsteps_rk;
#     long_name7:  =6  nmode.gt.cnmax, cnmax set in output.f cnmax=10000
#     long_name8:  =7  for ((id.eq.1,2).and.(uh.gt.1.d0).and.
#     long_name9:  ((uh-1.d0).lt.del_uh)).and.(cnper.gt.cnper_max_ebw)).
#     long_name10:   The ray is close to upper hybrid resonance.
#     long_name11:   It can be Xmode to close to the UH resonance.
#     long_name12:  =8  if ((vgrmods.gt.1.1).and. ((id.ne.10).and.
#     long_name13: (id.ne.12).and.(id.ne.13))) and if (id.eq.14);
#     long_name14:  =9  D/(N|gradD|) > toll_hamilt;
#     long_name15:  =10 in prep3d.f argexp>0;
#     long_name16:  =11 in prep3d fluxn(is).lt.0.0;
#     long_name17:  =12 nrayelt=nrelt;
#     long_name18:  =13 in RK drkgs2 small time step h.lt.1.d-11
#     long_name19:   can not get the given accuracy prmt4
#     long_name20:   =14, ray started with zero power (lt.1e-100)
# unlimited dimensions:
# current shape = (1, 100)
# filling on, default _FillValue of -2147483647 used}
