# %%
conda activate omfitenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install --upgrade omfit_classes

# %%
#%pip install omas

# %%
from omfit_classes import omfit_eqdsk
# Out:
# UserWarning: No `MDSplus` support: ModuleNotFoundError("No module named 'MDSplus'") (omfit_mds.py@24)

# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from uncertainties import ufloat
import numpy as np
from scipy.integrate import cumtrapz
from scipy.constants import mu_0
import os

# %%
#volume average
def vol_avg(geqdsk, prof, rho_prof = None): #rho_prof is only specified if integrating a quantity outside the geqdsk
    if rho_prof is not None:
        rho_geqdsk = geqdsk['RHOVN'] 
        prof_sized = np.interp(rho_geqdsk,rho_prof,prof)
        prof_sized_vol_int = omfit_eqdsk.fluxSurfaces.volume_integral(geqdsk['fluxSurfaces'], prof_sized)[-1]
        prof_sized_vol_avg = prof_sized_vol_int/omfit_eqdsk.fluxSurfaces.volume_integral(geqdsk['fluxSurfaces'], 1)[-1]
        return prof_sized_vol_avg
    
    else:
        prof_vol_int = omfit_eqdsk.fluxSurfaces.volume_integral(geqdsk['fluxSurfaces'], prof)[-1]
        prof_vol_avg = prof_vol_int/omfit_eqdsk.fluxSurfaces.volume_integral(geqdsk['fluxSurfaces'], 1)[-1]
        return prof_vol_avg

#H factor definitions
def vol_integral(geqdsk, prof, rho_prof = None): #rho_prof is only specified if integrating a quantity outside the geqdsk
    if rho_prof is not None:
        rho_geqdsk = geqdsk['RHOVN']
        prof_sized = np.interp(rho_geqdsk,rho_prof,prof)
        prof_sized_vol_int = omfit_eqdsk.fluxSurfaces.volume_integral(geqdsk['fluxSurfaces'], prof_sized)[-1]
        return prof_sized_vol_int
    
    else:
        prof_vol_int = omfit_eqdsk.fluxSurfaces.volume_integral(geqdsk['fluxSurfaces'], prof)[-1]
        return prof_vol_int

def taue_h_mode(x,a1=0.93,a2=0.15,a3=0.41,a4=-0.69,a5=1.97,a6=0.78,a7=0.58): #M = 2.5 for DT
    h_mode_vars = [x['ip'],x['bcentr'],x['density'],x['ptot_cps'],x['rsurf'],x['kappa'],x['eps']]
    return 0.0562*2.5**(0.19)*np.prod(np.power(h_mode_vars,np.array([a1,a2,a3,a4,a5,a6,a7])))

def taue_l_mode(x,a1=0.85,a2=1.2,a3=0.3,a4=0.5,a5=0.1,a6=0.2,a7=-0.5): #M = 2.5 for DT
    l_mode_vars = [x['ip'],x['rsurf'],x['aminor'],x['kappa'],x['density']/10,x['bcentr'],x['ptot_cps']] #this scaling law uses n20
    return 0.048*2.5**(0.5)*np.prod(np.power(x,np.array([a1,a2,a3,a4,a5,a6,a7])),axis=1)

def get_params_dict(gfile,ffile):
    ip = abs(ffile['ip'][-1])
    bt = abs(ffile['b0'][-1])
    
    rho_tor_norm = ffile['rho'][:]
    e_density_profile = ffile['ne'][-1] #10^19
    density_19_avg = vol_avg(gfile,e_density_profile,rho_tor_norm)
    
    Palpha = (ffile['pfuse'][-1] + ffile['pfusi'][-1]) #multiply by 5 would give fusion power, don't do for this
    Ptot = ffile['prfe'][-1] + ffile['prfi'][-1] + Palpha
    Rmaj = gfile['fluxSurfaces']['geo']['R'][-1]
    kappa = gfile['fluxSurfaces']['geo']['kap'][-1]
    aminor = gfile['fluxSurfaces']['geo']['a'][-1]
    eps = gfile['fluxSurfaces']['geo']['eps'][-1]
    params_dict = {'ip':ip,'bcentr':bt,'density':density_19_avg,'ptot_cps':Ptot,'rsurf':Rmaj,'kappa':kappa,'eps':eps,'aminor':aminor}
    return params_dict

def calc_H98y2(gfile,ffile):
    rho = ffile['rho'][:]
    ne_prof = ffile['ne'][-1,:] #10^19/m^3
    Te_prof = ffile['te'][-1,:] #keV
    ni_prof_tot = ffile['ni'][-1,:] + ffile['nz0'][-1,:] + ffile['nhe'][-1,:]
    Ti_prof = ffile['ti'][-1,:]
    #total_pressure = (ne_prof*Te_prof+ni_prof_tot*Ti_prof)*1602.2  #to convert to Pa (multiplication is for from eV to Joules)
    #use geqdsk pressure for now
    total_pressure = gfile['PRES']
    
    Wthr = vol_integral(gfile,(3/2)*total_pressure)/1e6 #MJ
    #print('Wthr =',Wthr)

    params_dict = get_params_dict(gfile,ffile)
    #print(params_dict)
    tau_H98y2 = taue_h_mode(params_dict,a1=0.93,a2=0.15,a3=0.41,a4=-0.69,a5=1.97,a6=0.78,a7=0.58)
    #print('tau_H98y2 =',tau_H98y2)
    tau_E = Wthr/params_dict['ptot_cps']
    #print('tau_E =',tau_E)
    H98y2 = tau_E/tau_H98y2
    #print('H98y2 =',H98y2)

    return H98y2

# %%
## First just find the fastran.nc and geqdsk file
ffile = '/pscratch/sd/h/hswils/github_repos/MANTA_DBSCANS/test_densevol_addKr/SCAN/work/fastran_tr_fastran_8/fastran.nc'
gfile = '/pscratch/sd/h/hswils/github_repos/MANTA_DBSCANS/test_densevol_addKr/SCAN/work/fastran_tr_fastran_8/g000001.00001'

rootgrp = Dataset(ffile)
geqdsk = omfit_eqdsk.OMFITeqdsk(gfile)
#print(rootgrp.variables)

## Some ffile variables
Rmaj = rootgrp['r0'][-1]
Bt = float(rootgrp['b0'][-1])
Ip = rootgrp['ip'][-1]
aminor = rootgrp['a0'][-1]

## Calculate Greenwald fraction
nebar = rootgrp['nebar'][-1]
n_Gr = Ip/(np.pi*aminor**2)
f_Gr = nebar/10/n_Gr #divide by 10 to switch from 10^19 to 10^20

## Calculate H factor
H98y2 = calc_H98y2(geqdsk,rootgrp)

## Calculate Angioni peaking
Gamma_NBI = 0

#Grab profiles
rho = rootgrp['rho'][:]
ne_prof = rootgrp['ne'][-1,:] #10^19/m^3
Te_prof = rootgrp['te'][-1,:] #keV
ni_prof_tot = rootgrp['ni'][-1,:] + rootgrp['nz0'][-1,:] + rootgrp['nhe'][-1,:]
Ti_prof = rootgrp['ti'][-1,:]
#p_prof = (ne_prof*Te_prof+ni_prof_tot*Ti_prof) #should be in keV*10**19/m**3 for Angioni beta equation  #*1602.2 to convert to Pa (multiplication is for from eV to Joules)
p_prof = geqdsk['PRES']/1602.2 #convert to 10^19/m^3

##compare pressures from g and f files
#plt.plot(rho,p_prof*1602.2)
#plt.plot(rho_geqdsk,pres_geqdsk)
# pres_f_vol_avg = vol_avg(geqdsk['fluxSurfaces'],p_prof*1602.2,rho)
# print(pres_g_vol_avg)
# print(pres_f_vol_avg)

#Calculate volume averages
ne_vol_avg = vol_avg(geqdsk,ne_prof,rho)
p_vol_avg = vol_avg(geqdsk,p_prof)
Te_vol_avg = vol_avg(geqdsk,Te_prof,rho)

#Calculate regression variables
nu_eff = 0.2*ne_vol_avg*Rmaj/(Te_vol_avg**2) #don't use line average for this density average
beta = 4.02e-3*p_vol_avg/(Bt**2)

n02 = ne_prof[int(0.2*len(ne_prof))]

#Calculate Angioni peaking
npeaking = ufloat(1.347,0.014) - ufloat(0.117,0.005)*np.log(nu_eff) + ufloat(1.331,0.117)*Gamma_NBI - ufloat(4.030,0.810)*beta

n_peak_left = npeaking.nominal_value-npeaking.std_dev
n_peak_right = npeaking.nominal_value+npeaking.std_dev
if n02/ne_vol_avg >= n_peak_left and n02/ne_vol_avg <= n_peak_right:
    print('pass')
else:
    print('fail')

# plt.plot(rootgrp['nbeam'][-1,:])
# plt.show()
print(rootgrp.variables)
# Out:
# fail
# {'time': <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'rho': <class 'netCDF4._netCDF4.Variable'>
# float64 rho(rho)
# unlimited dimensions:
# current shape = (101,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'r0': <class 'netCDF4._netCDF4.Variable'>
# float64 r0(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'b0': <class 'netCDF4._netCDF4.Variable'>
# float64 b0(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'a0': <class 'netCDF4._netCDF4.Variable'>
# float64 a0(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'amain': <class 'netCDF4._netCDF4.Variable'>
# float64 amain(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'zmain': <class 'netCDF4._netCDF4.Variable'>
# float64 zmain(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'we': <class 'netCDF4._netCDF4.Variable'>
# float64 we(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wi': <class 'netCDF4._netCDF4.Variable'>
# float64 wi(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wb': <class 'netCDF4._netCDF4.Variable'>
# float64 wb(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'betan': <class 'netCDF4._netCDF4.Variable'>
# float64 betan(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pnbe': <class 'netCDF4._netCDF4.Variable'>
# float64 pnbe(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pnbi': <class 'netCDF4._netCDF4.Variable'>
# float64 pnbi(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'prfe': <class 'netCDF4._netCDF4.Variable'>
# float64 prfe(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'prfi': <class 'netCDF4._netCDF4.Variable'>
# float64 prfi(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'prad': <class 'netCDF4._netCDF4.Variable'>
# float64 prad(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pei': <class 'netCDF4._netCDF4.Variable'>
# float64 pei(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pfuse': <class 'netCDF4._netCDF4.Variable'>
# float64 pfuse(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pfusi': <class 'netCDF4._netCDF4.Variable'>
# float64 pfusi(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pfuse_equiv': <class 'netCDF4._netCDF4.Variable'>
# float64 pfuse_equiv(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pfusi_equiv': <class 'netCDF4._netCDF4.Variable'>
# float64 pfusi_equiv(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'poh': <class 'netCDF4._netCDF4.Variable'>
# float64 poh(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'taue': <class 'netCDF4._netCDF4.Variable'>
# float64 taue(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'taui': <class 'netCDF4._netCDF4.Variable'>
# float64 taui(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tauth': <class 'netCDF4._netCDF4.Variable'>
# float64 tauth(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tautot': <class 'netCDF4._netCDF4.Variable'>
# float64 tautot(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tau98': <class 'netCDF4._netCDF4.Variable'>
# float64 tau98(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tau89': <class 'netCDF4._netCDF4.Variable'>
# float64 tau89(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'taunc': <class 'netCDF4._netCDF4.Variable'>
# float64 taunc(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tea': <class 'netCDF4._netCDF4.Variable'>
# float64 tea(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tia': <class 'netCDF4._netCDF4.Variable'>
# float64 tia(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nebar': <class 'netCDF4._netCDF4.Variable'>
# float64 nebar(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ip': <class 'netCDF4._netCDF4.Variable'>
# float64 ip(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ibs': <class 'netCDF4._netCDF4.Variable'>
# float64 ibs(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'inb': <class 'netCDF4._netCDF4.Variable'>
# float64 inb(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'irf': <class 'netCDF4._netCDF4.Variable'>
# float64 irf(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sn': <class 'netCDF4._netCDF4.Variable'>
# float64 sn(time)
# unlimited dimensions: time
# current shape = (3,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'rhob': <class 'netCDF4._netCDF4.Variable'>
# float64 rhob(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'te': <class 'netCDF4._netCDF4.Variable'>
# float64 te(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ti': <class 'netCDF4._netCDF4.Variable'>
# float64 ti(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ne': <class 'netCDF4._netCDF4.Variable'>
# float64 ne(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ni': <class 'netCDF4._netCDF4.Variable'>
# float64 ni(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nz0': <class 'netCDF4._netCDF4.Variable'>
# float64 nz0(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nz1': <class 'netCDF4._netCDF4.Variable'>
# float64 nz1(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'omega': <class 'netCDF4._netCDF4.Variable'>
# float64 omega(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'zeff': <class 'netCDF4._netCDF4.Variable'>
# float64 zeff(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'aimp': <class 'netCDF4._netCDF4.Variable'>
# float64 aimp(imp)
# unlimited dimensions:
# current shape = (2,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'zimp': <class 'netCDF4._netCDF4.Variable'>
# float64 zimp(imp)
# unlimited dimensions:
# current shape = (2,)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tep': <class 'netCDF4._netCDF4.Variable'>
# float64 tep(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'tip': <class 'netCDF4._netCDF4.Variable'>
# float64 tip(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nep': <class 'netCDF4._netCDF4.Variable'>
# float64 nep(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nip': <class 'netCDF4._netCDF4.Variable'>
# float64 nip(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'j_tot': <class 'netCDF4._netCDF4.Variable'>
# float64 j_tot(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'j_bs': <class 'netCDF4._netCDF4.Variable'>
# float64 j_bs(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'j_bs_0': <class 'netCDF4._netCDF4.Variable'>
# float64 j_bs_0(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'j_nb': <class 'netCDF4._netCDF4.Variable'>
# float64 j_nb(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'j_rf': <class 'netCDF4._netCDF4.Variable'>
# float64 j_rf(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'j_oh': <class 'netCDF4._netCDF4.Variable'>
# float64 j_oh(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pe_nb': <class 'netCDF4._netCDF4.Variable'>
# float64 pe_nb(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pe_rf': <class 'netCDF4._netCDF4.Variable'>
# float64 pe_rf(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'p_rad': <class 'netCDF4._netCDF4.Variable'>
# float64 p_rad(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'p_ohm': <class 'netCDF4._netCDF4.Variable'>
# float64 p_ohm(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'p_ei': <class 'netCDF4._netCDF4.Variable'>
# float64 p_ei(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pe_fus': <class 'netCDF4._netCDF4.Variable'>
# float64 pe_fus(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pe_ionization': <class 'netCDF4._netCDF4.Variable'>
# float64 pe_ionization(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pi_nb': <class 'netCDF4._netCDF4.Variable'>
# float64 pi_nb(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pi_rf': <class 'netCDF4._netCDF4.Variable'>
# float64 pi_rf(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pi_fus': <class 'netCDF4._netCDF4.Variable'>
# float64 pi_fus(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pi_cx': <class 'netCDF4._netCDF4.Variable'>
# float64 pi_cx(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pi_ionization': <class 'netCDF4._netCDF4.Variable'>
# float64 pi_ionization(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pe': <class 'netCDF4._netCDF4.Variable'>
# float64 pe(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pi': <class 'netCDF4._netCDF4.Variable'>
# float64 pi(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'torque_nb': <class 'netCDF4._netCDF4.Variable'>
# float64 torque_nb(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'q': <class 'netCDF4._netCDF4.Variable'>
# float64 q(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'shat': <class 'netCDF4._netCDF4.Variable'>
# float64 shat(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'fpol': <class 'netCDF4._netCDF4.Variable'>
# float64 fpol(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sigma': <class 'netCDF4._netCDF4.Variable'>
# float64 sigma(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'vloop': <class 'netCDF4._netCDF4.Variable'>
# float64 vloop(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'pmhd': <class 'netCDF4._netCDF4.Variable'>
# float64 pmhd(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'qmhd': <class 'netCDF4._netCDF4.Variable'>
# float64 qmhd(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ermhd': <class 'netCDF4._netCDF4.Variable'>
# float64 ermhd(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'wbeam': <class 'netCDF4._netCDF4.Variable'>
# float64 wbeam(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nbeam': <class 'netCDF4._netCDF4.Variable'>
# float64 nbeam(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'sion': <class 'netCDF4._netCDF4.Variable'>
# float64 sion(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'walp': <class 'netCDF4._netCDF4.Variable'>
# float64 walp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'betan_loc': <class 'netCDF4._netCDF4.Variable'>
# float64 betan_loc(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nhe': <class 'netCDF4._netCDF4.Variable'>
# float64 nhe(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chie': <class 'netCDF4._netCDF4.Variable'>
# float64 chie(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chie_etg': <class 'netCDF4._netCDF4.Variable'>
# float64 chie_etg(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chii': <class 'netCDF4._netCDF4.Variable'>
# float64 chii(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chiv': <class 'netCDF4._netCDF4.Variable'>
# float64 chiv(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chin': <class 'netCDF4._netCDF4.Variable'>
# float64 chin(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chieneo': <class 'netCDF4._netCDF4.Variable'>
# float64 chieneo(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chiineo': <class 'netCDF4._netCDF4.Variable'>
# float64 chiineo(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'fluxe': <class 'netCDF4._netCDF4.Variable'>
# float64 fluxe(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'fluxi': <class 'netCDF4._netCDF4.Variable'>
# float64 fluxi(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'fluxe_exp': <class 'netCDF4._netCDF4.Variable'>
# float64 fluxe_exp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'fluxi_exp': <class 'netCDF4._netCDF4.Variable'>
# float64 fluxi_exp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chie_exp': <class 'netCDF4._netCDF4.Variable'>
# float64 chie_exp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chii_exp': <class 'netCDF4._netCDF4.Variable'>
# float64 chii_exp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chiv_exp': <class 'netCDF4._netCDF4.Variable'>
# float64 chiv_exp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'volp': <class 'netCDF4._netCDF4.Variable'>
# float64 volp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ipol': <class 'netCDF4._netCDF4.Variable'>
# float64 ipol(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'g11': <class 'netCDF4._netCDF4.Variable'>
# float64 g11(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'g22': <class 'netCDF4._netCDF4.Variable'>
# float64 g22(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'g33': <class 'netCDF4._netCDF4.Variable'>
# float64 g33(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'gradrho': <class 'netCDF4._netCDF4.Variable'>
# float64 gradrho(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'area': <class 'netCDF4._netCDF4.Variable'>
# float64 area(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'aminor': <class 'netCDF4._netCDF4.Variable'>
# float64 aminor(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'rmajor': <class 'netCDF4._netCDF4.Variable'>
# float64 rmajor(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'shift': <class 'netCDF4._netCDF4.Variable'>
# float64 shift(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'delta': <class 'netCDF4._netCDF4.Variable'>
# float64 delta(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'kappa': <class 'netCDF4._netCDF4.Variable'>
# float64 kappa(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chin_exp': <class 'netCDF4._netCDF4.Variable'>
# float64 chin_exp(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'chie_paleo': <class 'netCDF4._netCDF4.Variable'>
# float64 chie_paleo(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'nue_s': <class 'netCDF4._netCDF4.Variable'>
# float64 nue_s(time, rho)
# unlimited dimensions: time
# current shape = (3, 101)
# filling on, default _FillValue of 9.969209968386869e+36 used}

# %%
rho = rootgrp['rho'][:]

ne = rootgrp['ne'][-1,:]
nebar = rootgrp['nebar'][-1]
ni = rootgrp['ni'][-1,:] + rootgrp['nz0'][-1,:] + rootgrp['nhe'][-1,:]

te = rootgrp['te'][-1,:]
teavg = rootgrp['tea'][-1]
ti = rootgrp['ti'][-1,:]
tiavg = rootgrp['tia'][-1]

prfe = rootgrp['pe_rf'][-1,:]
prfe_int = rootgrp['prfe'][-1]
prfi = rootgrp['pi_rf'][-1,:]
prfi_int = rootgrp['prfi'][-1]

#betan = rootgrp['betan_loc'][-1,:]
#betan = p_vol_avg*1602.2*2*mu_0/Bt**2#*(aminor*Bt/Ip) ##FIXME doesn't make sense #approximate, check which B to use
betan_num = rootgrp['betan'][-1]

ipol = rootgrp['ipol'][-1,:]
ip = rootgrp['ip'][-1]

pfuse = rootgrp['pe_fus'][-1,:]
pfuse_int = rootgrp['pfuse'][-1]
pfusi = rootgrp['pi_fus'][-1,:]
pfusi_int = rootgrp['pfusi'][-1]

q = rootgrp['q'][-1,:]

jbs = rootgrp['j_bs'][-1,:]
ibs = rootgrp['ibs'][-1]
jrf = rootgrp['j_rf'][-1,:]
irf = rootgrp['irf'][-1]
jtot = rootgrp['j_tot'][-1,:]

fluxe = rootgrp['fluxe'][-1,:]
fluxe_exp = rootgrp['fluxe_exp'][-1,:]
fluxi = rootgrp['fluxi'][-1,:]
fluxi_exp = rootgrp['fluxi_exp'][-1,:]

fig, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9)) =plt.subplots(3,3,figsize =(8,6),dpi = 150)
lw = 2
c1 = 'green'
c2 = 'lime'
c3 = 'magenta'
c4 = 'darkviolet'
c5 = 'dodgerblue'
c6 = 'cyan'

ax1.plot(rho,ne,color = c1,linewidth = lw,label='electron')
ax1.plot(rho,ni,color = c2,linewidth = lw,linestyle = 'dashed',label='ion')
ax2.plot(rho,te,color = c1,linewidth = lw)
ax2.plot(rho,ti,color = c2,linewidth = lw,linestyle = 'dashed')
ax1.set_ylabel('dens [10$^{19}$/m$^3$]')
ax2.set_ylabel('temp [keV]')
ax1.legend()

ax3.plot(rho,prfe,color = c1,linewidth = lw)
ax3.plot(rho,prfi,color = c2,linewidth = lw,linestyle = 'dashed')
#ax4.plot(rho,betan,color = c3,linewidth = lw)
ax3.set_ylabel('qaux [MW/m$^3$]')
ax3.text(0.5,0.8,'{:.1f} MW'.format(prfe_int),color = c1, transform = ax3.transAxes)
ax3.text(0.5,0.6,'{:.1f} MW'.format(prfi_int),color = c2, transform = ax3.transAxes)
ax4.set_ylabel('betan')
ax4.text(0.5,0.8,'betan = {:.1f}'.format(betan_num),color = c3, transform = ax4.transAxes)

ax5.plot(rho,q,color = c3,linewidth = lw)
ax5.set_ylabel('q')

ax6.plot(rho,ipol,color = c3, linewidth = lw)
ax6.set_ylabel('ipol')
ax6.text(0.5,0.8,'{:.1f} MA'.format(ip),color = c3,transform = ax6.transAxes)

#ax7.plot(rho,jtot,color = c3,linewidth = lw)
ax7.plot(rho,jrf,color = c4,linewidth = lw,linestyle = 'dashed')
ax7.plot(rho,jbs,color = c5, linewidth =lw, linestyle='dashed')
ax7.text(0.5,0.8,'i_rf = {:.1f}'.format(irf),color = c4,transform = ax7.transAxes)
ax7.text(0.5,0.6,'i_bs = {:.1f}'.format(ibs),color = c5,transform = ax7.transAxes)
ax7.set_ylabel('current density')

ax8.plot(rho,5*pfuse,color = c1,linewidth = lw)
ax8.plot(rho,5*pfusi,color = c2,linewidth = lw,linestyle = 'dashed')
ax8.set_ylabel('pfus')
ax8.text(0.5,0.8,'{:.1f} MW'.format(5*pfuse_int),color = c1,transform = ax8.transAxes)
ax8.text(0.5,0.6,'{:.1f} MW'.format(5*pfusi_int),color = c2,transform = ax8.transAxes)

ax9.plot(rho,fluxe,'.',color =c1,linewidth = lw)
ax9.plot(rho,fluxe_exp,color = c1,linewidth = lw,linestyle = 'dashed')
ax9.plot(rho,fluxi,'.',color = c2,linewidth = lw)
ax9.plot(rho,fluxi_exp,color = c2,linewidth = lw,linestyle = 'dashed')
ax9.set_ylabel('e flux [W/m$^3$]')

fig.tight_layout()
plt.show()
