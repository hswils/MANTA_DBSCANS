# %%
# !pip install xarray
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import xarray as xr
from sys import argv
import matplotlib.pyplot as plt
import numpy as np

ffile = '/pscratch/sd/h/hswils/github_repos/MANTA_DBSCANS/BASECASE_TORIC/SCAN/work/rf_ic_toric_5/toric.nc'

rootgrp = xr.open_dataset(ffile)

Xplasma = rootgrp['Xplasma']
Zplasma = rootgrp['Zplasma']
power_absorbed_2D = rootgrp['TDPwIF']
pa_2D_firstharm = rootgrp['TdPwIH']

fig, (ax1) = plt.subplots(1,1)

#print(power_absorbed_2D.coords)

CS = ax1.contourf(Xplasma,Zplasma,power_absorbed_2D.sel(SpecDim=0))
ax1.set_aspect('equal')
colorbar = fig.colorbar(CS)
colorbar.set_label('Power absorbed ($\mathrm{W}/\mathrm{cm}^3$)',fontsize = 16)
ax1.set_xlabel('X (cm)',fontsize = 16)
ax1.set_ylabel('Z (cm)',fontsize = 16)
#ax1.set_xlim(-150,-100)
#ax1.set_ylim(-20,20)

print(power_absorbed_2D)
# Out:
# <xarray.DataArray 'TDPwIF' (ThetaDim: 512, NpsiDim: 503, SpecDim: 6)> Size: 12MB
# [1545216 values with dtype=float64]
# Dimensions without coordinates: ThetaDim, NpsiDim, SpecDim
# Attributes:
#     long_name:  $P_i^{Fund}$                            Two-Dim Power Absorbe...
#     units:      $W/cm^3/MW_{abs}]$

# %%
import xarray as xr
from sys import argv
import matplotlib.pyplot as plt
import numpy as np

ffile = '/pscratch/sd/h/hswils/github_repos/MANTA_DBSCANS/BASECASE_TORIC/SCAN/work/rf_ic_toric_5/toric.nc'

rootgrp = xr.open_dataset(ffile)

Xplasma = rootgrp['Xplasma']
Zplasma = rootgrp['Zplasma']
power_absorbed_2D = rootgrp['TDPwIF']
pa_2D_firstharm = rootgrp['TdPwIH']

fig, (ax1) = plt.subplots(1,1)

#print(power_absorbed_2D.coords)

CS = ax1.contourf(Xplasma,Zplasma,power_absorbed_2D.sel(SpecDim=0))
ax1.set_aspect('equal')
colorbar = fig.colorbar(CS)
colorbar.set_label('Power absorbed ($\mathrm{W}/\mathrm{cm}^3$)')
ax1.set_xlabel('X (cm)')
ax1.set_ylabel('Z (cm)')
ax1.set_xlim(-150,-100)
ax1.set_ylim(-20,20)

print(power_absorbed_2D)
# Out:
# <xarray.DataArray 'TDPwIF' (ThetaDim: 512, NpsiDim: 503, SpecDim: 6)> Size: 12MB
# [1545216 values with dtype=float64]
# Dimensions without coordinates: ThetaDim, NpsiDim, SpecDim
# Attributes:
#     long_name:  $P_i^{Fund}$                            Two-Dim Power Absorbe...
#     units:      $W/cm^3/MW_{abs}]$
