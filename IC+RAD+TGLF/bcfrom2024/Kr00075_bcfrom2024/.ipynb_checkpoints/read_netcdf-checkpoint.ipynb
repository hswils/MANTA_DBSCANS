# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from uncertainties import ufloat
import numpy as np
from scipy.constants import mu_0
import os

# %%
ipsfile = '/global/common/software/atom/perlmutter/data/radas_dir/output/argon.nc'
rtgrp = Dataset(ipsfile)

# %%
plt.loglog(rtgrp['coronal_Lz'])

# %%
print(rtgrp.variables)
# Out:
# {'evolution_start': <class 'netCDF4.Variable'>
# float64 evolution_start()
#     _FillValue: nan
#     units: second
# unlimited dimensions:
# current shape = ()
# filling on, 'evolution_stop': <class 'netCDF4.Variable'>
# float64 evolution_stop()
#     _FillValue: nan
#     units: second
# unlimited dimensions:
# current shape = ()
# filling on, 'ne_tau': <class 'netCDF4.Variable'>
# float64 ne_tau(dim_ne_tau)
#     _FillValue: nan
#     units: second / meter ** 3
# unlimited dimensions:
# current shape = (5,)
# filling on, 'electron_density': <class 'netCDF4.Variable'>
# float64 electron_density(dim_electron_density)
#     _FillValue: nan
#     units: 1 / meter ** 3
# unlimited dimensions:
# current shape = (26,)
# filling on, 'electron_temp': <class 'netCDF4.Variable'>
# float64 electron_temp(dim_electron_temp)
#     _FillValue: nan
#     units: electron_volt
# unlimited dimensions:
# current shape = (48,)
# filling on, 'reference_electron_density': <class 'netCDF4.Variable'>
# ...
